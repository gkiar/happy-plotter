# %%
require(corrplot)
rm(list=ls())
load('mat1.RData')

# %%
cols <- c(rep("blue",6), rep('darkred',10),rep('green',4),rep('purple',4))
#tmp <- c(rep(1,6),rep(2,4),rep(3,10),rep(4,4))
tmp <- as.numeric(table(cols))

# %%
corrplot(M, method='color',tl.col=cols)
corrRect(tmp,col=unique(cols),lwd=4)
# Out:
# Plot with title “”
